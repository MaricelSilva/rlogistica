# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Lectura de datos 
train = pd.read_csv("C:/Users/User/Desktop/framingham.csv")

# %%
train.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
train[['BMI','TenYearCHD']]. head()
# Out:
#      BMI  TenYearCHD
# 0  26.97           0
# 1  28.73           0
# 2  25.34           0
# 3  28.58           1
# 4  23.10           0

# %%
train[['BMI','prevalentHyp']]. head()
# Out:
#      BMI  prevalentHyp
# 0  26.97             0
# 1  28.73             0
# 2  25.34             0
# 3  28.58             1
# 4  23.10             0

# %%
train[['BMI','prevalentHyp']].plot.scatter(x='BMI', y='prevalentHyp')
# Out:
# <Axes: xlabel='BMI', ylabel='prevalentHyp'>

# %%
w = 0.5
b = 10

# %%
x = np.linspace(0,train['BMI'].max(),50)
y = 1/(1+np.exp(-w*x+b))

train.plot.scatter(x='BMI', y='prevalentHyp')
plt.plot(x,y, '-r')
plt.ylim(0,train['prevalentHyp'].max()*1.1)
plt.show()
